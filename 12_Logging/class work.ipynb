# %%
import logging

logging.basicConfig(filename='app.log', filemode='w',level=logging.DEBUG,format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',datefmt='%Y-%m-%d %H:%M:%S')

#Message

logging.debug('This debuging message!!!')
logging.error('this is error message!!!')
logging.critical('this is critical message!!!')
logging.warning('this is warning message!!!')
logging.info('this is info message!!!')

# %%
log1 = logging.getLogger('Debug')
log1.setLevel(logging.DEBUG)
log1.debug('This is Log of Debug!!')

log2 = logging.getLogger('Warning')
log2.setLevel(logging.WARNING)
log2.warning('This is Log of Warning!!')
